# %% [markdown]
# # Kaggle yarışmalarında vs kullanabileceğimiz ieş yarar bir kütüphane

# %%
pip install lazypredict
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lazypredict in c:\users\hp\appdata\roaming\python\python313\site-packages (0.2.16)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (8.1.8)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (1.6.1)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (2.2.3)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (4.67.1)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: lightgbm in c:\users\hp\appdata\roaming\python\python313\site-packages (from lazypredict) (4.6.0)
# Requirement already satisfied: xgboost in c:\users\hp\appdata\roaming\python\python313\site-packages (from lazypredict) (3.0.5)
# Requirement already satisfied: pytest-runner in c:\users\hp\appdata\roaming\python\python313\site-packages (from lazypredict) (6.0.1)
# Requirement already satisfied: mlflow>=2.0.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from lazypredict) (3.4.0)
# Requirement already satisfied: mlflow-skinny==3.4.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mlflow>=2.0.0->lazypredict) (3.4.0)
# Requirement already satisfied: mlflow-tracing==3.4.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mlflow>=2.0.0->lazypredict) (3.4.0)
# Requirement already satisfied: Flask<4 in c:\programdata\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (3.1.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\programdata\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (1.16.2)
# Requirement already satisfied: cryptography<46,>=43.0.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (44.0.1)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mlflow>=2.0.0->lazypredict) (7.1.0)
# Requirement already satisfied: fastmcp<3,>=2.0.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mlflow>=2.0.0->lazypredict) (2.12.4)
# Requirement already satisfied: graphene<4 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mlflow>=2.0.0->lazypredict) (3.4.3)
# Requirement already satisfied: matplotlib<4 in c:\programdata\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (3.10.0)
# Requirement already satisfied: numpy<3 in c:\programdata\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (2.1.3)
# Requirement already satisfied: pyarrow<22,>=4.0.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (19.0.0)
# Requirement already satisfied: scipy<2 in c:\programdata\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow>=2.0.0->lazypredict) (2.0.39)
# Requirement already satisfied: waitress<4 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mlflow>=2.0.0->lazypredict) (3.0.2)
# Requirement already satisfied: cachetools<7,>=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (5.5.1)
# Requirement already satisfied: cloudpickle<4 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (3.0.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (0.67.0)
# Requirement already satisfied: fastapi<1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (0.118.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (8.5.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (1.37.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (1.37.0)
# Requirement already satisfied: packaging<26 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (24.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (5.29.3)
# Requirement already satisfied: pydantic<3,>=1.10.8 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (2.11.9)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (1.1.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\programdata\anaconda3\lib\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (4.12.2)
# Requirement already satisfied: uvicorn<1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (0.37.0)
# Requirement already satisfied: Mako in c:\programdata\anaconda3\lib\site-packages (from alembic!=1.10.0,<2->mlflow>=2.0.0->lazypredict) (1.2.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->lazypredict) (0.4.6)
# Requirement already satisfied: cffi>=1.12 in c:\programdata\anaconda3\lib\site-packages (from cryptography<46,>=43.0.0->mlflow>=2.0.0->lazypredict) (1.17.1)
# Requirement already satisfied: google-auth~=2.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (2.41.1)
# Requirement already satisfied: pywin32>=304 in c:\users\hp\appdata\roaming\python\python313\site-packages (from docker<8,>=4.0.0->mlflow>=2.0.0->lazypredict) (311)
# Requirement already satisfied: urllib3>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow>=2.0.0->lazypredict) (2.3.0)
# Requirement already satisfied: starlette<0.49.0,>=0.40.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from fastapi<1->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (0.48.0)
# Requirement already satisfied: authlib>=1.5.2 in c:\users\hp\appdata\roaming\python\python313\site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (1.6.4)
# Requirement already satisfied: cyclopts>=3.0.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (3.24.0)
# Requirement already satisfied: exceptiongroup>=1.2.2 in c:\users\hp\appdata\roaming\python\python313\site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (1.3.0)
# Requirement already satisfied: httpx>=0.28.1 in c:\programdata\anaconda3\lib\site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (0.28.1)
# Requirement already satisfied: mcp<2.0.0,>=1.12.4 in c:\users\hp\appdata\roaming\python\python313\site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (1.15.0)
# Requirement already satisfied: openapi-core>=0.19.5 in c:\users\hp\appdata\roaming\python\python313\site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (0.19.5)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (0.5.1)
# Requirement already satisfied: pyperclip>=1.9.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (1.11.0)
# Requirement already satisfied: rich>=13.9.4 in c:\programdata\anaconda3\lib\site-packages (from fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (13.9.4)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (3.1.1)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\programdata\anaconda3\lib\site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in c:\programdata\anaconda3\lib\site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in c:\programdata\anaconda3\lib\site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\programdata\anaconda3\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\programdata\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hp\appdata\roaming\python\python313\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from graphene<4->mlflow>=2.0.0->lazypredict) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from graphene<4->mlflow>=2.0.0->lazypredict) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\programdata\anaconda3\lib\site-packages (from graphene<4->mlflow>=2.0.0->lazypredict) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in c:\programdata\anaconda3\lib\site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (3.21.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (3.2.0)
# Requirement already satisfied: anyio>=4.5 in c:\programdata\anaconda3\lib\site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (4.7.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (0.4.1)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\programdata\anaconda3\lib\site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (4.23.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\programdata\anaconda3\lib\site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (2.6.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (3.0.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (0.58b0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->lazypredict) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas->lazypredict) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow>=2.0.0->lazypredict) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (2025.7.14)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\programdata\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (0.4.8)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->lazypredict) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow>=2.0.0->lazypredict) (3.1.1)
# Requirement already satisfied: sniffio>=1.1 in c:\programdata\anaconda3\lib\site-packages (from anyio>=4.5->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (1.3.0)
# Requirement already satisfied: h11>=0.8 in c:\programdata\anaconda3\lib\site-packages (from uvicorn<1->mlflow-skinny==3.4.0->mlflow>=2.0.0->lazypredict) (0.16.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.12->cryptography<46,>=43.0.0->mlflow>=2.0.0->lazypredict) (2.21)
# Requirement already satisfied: attrs>=23.1.0 in c:\programdata\anaconda3\lib\site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (24.3.0)
# Requirement already satisfied: docstring-parser>=0.15 in c:\users\hp\appdata\roaming\python\python313\site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (1.3.1)
# Requirement already satisfied: docutils in c:\programdata\anaconda3\lib\site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=3.0.0->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (0.21.2)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx>=0.28.1->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (1.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from Jinja2>=3.1.2->Flask<4->mlflow>=2.0.0->lazypredict) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.12.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (0.22.3)
# Requirement already satisfied: isodate in c:\users\hp\appdata\roaming\python\python313\site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (0.7.2)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (0.3.4)
# Requirement already satisfied: more-itertools in c:\programdata\anaconda3\lib\site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (10.3.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (0.7.2)
# Requirement already satisfied: parse in c:\users\hp\appdata\roaming\python\python313\site-packages (from openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (1.20.2)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (0.4.4)
# Requirement already satisfied: rfc3339-validator in c:\programdata\anaconda3\lib\site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in c:\users\hp\appdata\roaming\python\python313\site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi-core>=0.19.5->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (1.12.0)
# Requirement already satisfied: email-validator>=2.0.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (2.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\hp\appdata\roaming\python\python313\site-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (2.8.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp<3,>=2.0.0->mlflow>=2.0.0->lazypredict) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import lazypredict

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np

# %%
diabetes  = datasets.load_diabetes()

# %%
diabetes.DESCR
# Out:
# '.. _diabetes_dataset:\n\nDiabetes dataset\n----------------\n\nTen baseline variables, age, sex, body mass index, average blood\npressure, and six blood serum measurements were obtained for each of n =\n442 diabetes patients, as well as the response of interest, a\nquantitative measure of disease progression one year after baseline.\n\n**Data Set Characteristics:**\n\n:Number of Instances: 442\n\n:Number of Attributes: First 10 columns are numeric predictive values\n\n:Target: Column 11 is a quantitative measure of disease progression one year after baseline\n\n:Attribute Information:\n    - age     age in years\n    - sex\n    - bmi     body mass index\n    - bp      average blood pressure\n    - s1      tc, total serum cholesterol\n    - s2      ldl, low-density lipoproteins\n    - s3      hdl, high-density lipoproteins\n    - s4      tch, total cholesterol / HDL\n    - s5      ltg, possibly log of serum triglycerides level\n    - s6      glu, blood sugar level\n\nNote: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).\n\nSource URL:\nhttps://www4.stat.ncsu.edu/~boos/var.select/diabetes.html\n\nFor more information see:\nBradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.\n(https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)\n'

# %%
X, y = shuffle(diabetes.data, diabetes.target, random_state=13)
X = X.astype(np.float32)

# %%
offset = int(X.shape[0] * 0.9)

X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]

# %%
X_train
# Out:
# array([[-0.00551456, -0.04464164,  0.05630714, ...,  0.03799897,
#          0.05078203,  0.0569118 ],
#        [-0.02004471, -0.04464164, -0.08488624, ..., -0.05167075,
#         -0.08237869, -0.04664087],
#        [-0.06726771, -0.04464164, -0.05901875, ..., -0.03949338,
#          0.00200444,  0.02377494],
#        ...,
#        [-0.02367725, -0.04464164, -0.06979687, ..., -0.03949338,
#         -0.08913335, -0.05078298],
#        [ 0.07440129, -0.04464164,  0.114509  , ..., -0.00259226,
#         -0.00061174, -0.0052198 ],
#        [ 0.01991321,  0.05068012,  0.01427248, ...,  0.03430886,
#          0.04666178,  0.09004866]], dtype=float32)

# %%
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000463 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 640
# [LightGBM] [Info] Number of data points in the train set: 397, number of used features: 10
# [LightGBM] [Info] Start training from score 151.722922
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
print(models)
# Out:
#                                Adjusted R-Squared  R-Squared   RMSE  \
# Model
# ExtraTreesRegressor                          0.38       0.52  54.22
# OrthogonalMatchingPursuitCV                  0.37       0.52  54.39
# Lasso                                        0.37       0.52  54.46
# LassoLars                                    0.37       0.52  54.46
# LarsCV                                       0.37       0.51  54.54
# LassoCV                                      0.37       0.51  54.59
# PassiveAggressiveRegressor                   0.37       0.51  54.74
# LassoLarsIC                                  0.36       0.51  54.83
# SGDRegressor                                 0.36       0.51  54.85
# Ridge                                        0.36       0.51  54.91
# RidgeCV                                      0.36       0.51  54.91
# BayesianRidge                                0.36       0.51  54.94
# LassoLarsCV                                  0.36       0.51  54.96
# TransformedTargetRegressor                   0.36       0.51  54.96
# LinearRegression                             0.36       0.51  54.96
# Lars                                         0.36       0.50  55.09
# ElasticNetCV                                 0.36       0.50  55.20
# HuberRegressor                               0.36       0.50  55.24
# RandomForestRegressor                        0.35       0.50  55.48
# AdaBoostRegressor                            0.34       0.49  55.88
# LGBMRegressor                                0.34       0.49  55.93
# HistGradientBoostingRegressor                0.34       0.49  56.08
# PoissonRegressor                             0.32       0.48  56.61
# ElasticNet                                   0.30       0.46  57.49
# KNeighborsRegressor                          0.30       0.46  57.57
# OrthogonalMatchingPursuit                    0.29       0.45  57.87
# BaggingRegressor                             0.29       0.45  57.92
# GradientBoostingRegressor                    0.25       0.42  59.70
# TweedieRegressor                             0.24       0.42  59.81
# XGBRegressor                                 0.22       0.40  60.60
# GammaRegressor                               0.22       0.40  60.61
# RANSACRegressor                              0.20       0.38  61.40
# LinearSVR                                    0.12       0.32  64.66
# ExtraTreeRegressor                           0.00       0.23  68.73
# NuSVR                                       -0.07       0.18  71.06
# SVR                                         -0.10       0.15  72.04
# DummyRegressor                              -0.30      -0.00  78.37
# QuantileRegressor                           -0.35      -0.04  79.84
# DecisionTreeRegressor                       -0.47      -0.14  83.42
# GaussianProcessRegressor                    -0.77      -0.37  91.51
# MLPRegressor                                -1.87      -1.22 116.51
# KernelRidge                                 -5.04      -3.67 169.06
#
#                                Time Taken
# Model
# ExtraTreesRegressor                  0.31
# OrthogonalMatchingPursuitCV          0.01
# Lasso                                0.01
# LassoLars                            0.01
# LarsCV                               0.02
# LassoCV                              0.09
# PassiveAggressiveRegressor           0.01
# LassoLarsIC                          0.02
# SGDRegressor                         0.01
# Ridge                                0.02
# RidgeCV                              0.02
# BayesianRidge                        0.07
# LassoLarsCV                          0.02
# TransformedTargetRegressor           0.01
# LinearRegression                     0.01
# Lars                                 0.02
# ElasticNetCV                         0.12
# HuberRegressor                       0.02
# RandomForestRegressor                0.31
# AdaBoostRegressor                    0.18
# LGBMRegressor                        0.05
# HistGradientBoostingRegressor        0.14
# PoissonRegressor                     0.01
# ElasticNet                           0.02
# KNeighborsRegressor                  0.02
# OrthogonalMatchingPursuit            0.01
# BaggingRegressor                     0.09
# GradientBoostingRegressor            0.18
# TweedieRegressor                     0.01
# XGBRegressor                         0.69
# GammaRegressor                       0.15
# RANSACRegressor                      0.10
# LinearSVR                            0.01
# ExtraTreeRegressor                   0.02
# NuSVR                                0.03
# SVR                                  0.02
# DummyRegressor                       0.01
# QuantileRegressor                    0.05
# DecisionTreeRegressor                0.06
# GaussianProcessRegressor             0.03
# MLPRegressor                         0.25
# KernelRidge                          0.02
